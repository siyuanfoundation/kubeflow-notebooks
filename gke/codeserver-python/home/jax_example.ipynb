# %%
import jax
devices = jax.devices()
print("All devices:", devices)

if devices:
  # Inspect the first device's kind
  first_device = devices[0]
  device_kind = first_device.device_kind
  print(f"Device Kind: {device_kind}")
